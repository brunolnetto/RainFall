# %%
# !pip install contextily
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting contextily
#   Downloading contextily-1.5.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting geopy (from contextily)
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: matplotlib in /home/brunolnetto/.local/lib/python3.8/site-packages (from contextily) (3.7.4)
# Collecting mercantile (from contextily)
#   Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: pillow in /home/brunolnetto/.local/lib/python3.8/site-packages (from contextily) (10.1.0)
# Collecting rasterio (from contextily)
#   Downloading rasterio-1.3.9-cp38-cp38-manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from contextily) (2.27.1)
# Requirement already satisfied: joblib in /home/brunolnetto/.local/lib/python3.8/site-packages (from contextily) (1.3.2)
# Requirement already satisfied: xyzservices in /home/brunolnetto/.local/lib/python3.8/site-packages (from contextily) (2023.10.0)
# Collecting geographiclib<3,>=1.52 (from geopy->contextily)
#   Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /home/brunolnetto/.local/lib/python3.8/site-packages (from matplotlib->contextily) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/brunolnetto/.local/lib/python3.8/site-packages (from matplotlib->contextily) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/brunolnetto/.local/lib/python3.8/site-packages (from matplotlib->contextily) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/brunolnetto/.local/lib/python3.8/site-packages (from matplotlib->contextily) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.20 in /home/brunolnetto/.local/lib/python3.8/site-packages (from matplotlib->contextily) (1.24.1)
# Requirement already satisfied: packaging>=20.0 in /home/brunolnetto/.local/lib/python3.8/site-packages (from matplotlib->contextily) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/brunolnetto/.local/lib/python3.8/site-packages (from matplotlib->contextily) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/brunolnetto/.local/lib/python3.8/site-packages (from matplotlib->contextily) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/brunolnetto/.local/lib/python3.8/site-packages (from matplotlib->contextily) (6.1.1)
# Requirement already satisfied: click>=3.0 in /usr/local/lib/python3.8/dist-packages (from mercantile->contextily) (8.1.3)
# Collecting affine (from rasterio->contextily)
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: attrs in /home/brunolnetto/.local/lib/python3.8/site-packages (from rasterio->contextily) (23.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from rasterio->contextily) (2022.5.18.1)
# Requirement already satisfied: cligj>=0.5 in /home/brunolnetto/.local/lib/python3.8/site-packages (from rasterio->contextily) (0.7.2)
# Collecting snuggs>=1.4.1 (from rasterio->contextily)
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: click-plugins in /home/brunolnetto/.local/lib/python3.8/site-packages (from rasterio->contextily) (1.1.1)
# Requirement already satisfied: setuptools in /home/brunolnetto/.local/lib/python3.8/site-packages (from rasterio->contextily) (69.0.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->contextily) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.8/dist-packages (from requests->contextily) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->contextily) (3.3)
# Requirement already satisfied: zipp>=3.1.0 in /home/brunolnetto/.local/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib->contextily) (3.17.0)
# Requirement already satisfied: six>=1.5 in /home/brunolnetto/.local/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.16.0)
# Downloading contextily-1.5.0-py3-none-any.whl (17 kB)
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 kB 2.8 MB/s eta 0:00:00MB/s eta 0:00:01
# Downloading rasterio-1.3.9-cp38-cp38-manylinux2014_x86_64.whl (20.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.7/20.7 MB 6.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Installing collected packages: snuggs, mercantile, geographiclib, affine, rasterio, geopy, contextily
# Successfully installed affine-2.4.0 contextily-1.5.0 geographiclib-2.0 geopy-2.4.1 mercantile-1.2.1 rasterio-1.3.9 snuggs-1.4.7

# %%
import geopandas
import geodatasets
import contextily as cx

# %%
df = geopandas.read_file(geodatasets.get_path("nybb"))
ax = df.plot(figsize=(10, 10), alpha=0.5, edgecolor="k")

df.crs
# Out:
# <Projected CRS: EPSG:2263>
# Name: NAD83 / New York Long Island (ftUS)
# Axis Info [cartesian]:
# - X[east]: Easting (US survey foot)
# - Y[north]: Northing (US survey foot)
# Area of Use:
# - name: United States (USA) - New York - counties of Bronx; Kings; Nassau; New York; Queens; Richmond; Suffolk.
# - bounds: (-74.26, 40.47, -71.8, 41.3)
# Coordinate Operation:
# - name: SPCS83 New York Long Island zone (US Survey feet)
# - method: Lambert Conic Conformal (2SP)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
df_wm = df.to_crs(epsg=3857)

# %%
ax = df.plot(figsize=(10, 10), alpha=0.5, edgecolor="k")
cx.add_basemap(ax, crs=df.crs)

# %%
ax = df_wm.plot(figsize=(10, 10), alpha=0.5, edgecolor="k")
cx.add_basemap(ax, source=cx.providers.CartoDB.Positron)
ax.set_axis_off()

# %%
ax = df_wm.plot(figsize=(10, 10), alpha=0.5, edgecolor="k")
cx.add_basemap(ax, source=cx.providers.CartoDB.PositronNoLabels)
cx.add_basemap(ax, source=cx.providers.CartoDB.PositronOnlyLabels)
