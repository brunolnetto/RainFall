# %%
import pytest
import ipytest
import json

ipytest.autoconfig()

# %%
delimiter = ','
def unwrap(str_):
    return str_.split(delimiter)

def inverse_dict(dict_):
    _dict = {}
    
    for key, values in dict_.items():
        for value in values:
            _dict[str(value)] = unwrap(key)
    
    return _dict

def flatten(l):
    return [item for sublist in l for item in sublist]

def json_prettify(json_):
    return json.dumps(json_, indent=4);

# %%
# %%ipytest
#
# # define the tests
# def test_unwrap():
#     assert unwrap('1,2,3') == ['1','2','3']
#
# def test_inverse_dict():
#     assert inverse_dict(
#         {'a': [1, 2], 'b': [3, 4]}
#     ) == {
#             '1': ['a'],
#             '2': ['a'],
#             '3': ['b'],
#             '4': ['b']
#          }
#
# def test_inverse_dict():
#     assert inverse_dict(
#         {'a': [1, 2], 'b': [3, 4]}
#     ) == {
#             '1': ['a'],
#             '2': ['a'],
#             '3': ['b'],
#             '4': ['b']
#          }
#
# def test_flatten():
#     assert flatten([[1, 2], [3, 4]]) == [1, 2, 3, 4]
#
# def test_json_prettify():
#     assert json_prettify({'a': 1, 'b': 2}) == '{\n    "a": 1,\n    "b": 2\n}'
# Out:
# ....                                                                                         [100%]
# 4 passed in 0.01s

# %%
import json

with open('./language_applications.json') as f:
    languages = json.load(f)

print(json_prettify(languages))
# Out:
# {
#     "Python": [
#         "Web development",
#         "scientific computing",
#         "data analysis",
#         "artificial intelligence",
#         "automation",
#         "machine learning"
#     ],
#     "Java": [
#         "Enterprise software development",
#         "Android app development",
#         "web development",
#         "big data processing",
#         "scientific computing",
#         "gaming"
#     ],
#     "JavaScript": [
#         "Web development",
#         "front-end development",
#         "server-side development",
#         "desktop applications",
#         "mobile applications",
#         "game development"
#     ],
#     "C++": [
#         "Operating systems",
#         "gaming",
#         "database systems",
#         "compilers",
#         "finance",
#         "scientific computing",
#         "artificial intelligence",
#         "robotics"
#     ],
#     "C#": [
#         "Windows desktop applications",
#         "game development",
#         "web development",
#         "mobile app development",
#         "enterprise software development"
#     ],
#     "Ruby": [
#         "Web development",
#         "rapid prototyping",
#         "scripting",
#         "automation",
#         "testing",
#         "game development"
#     ],
#     "PHP": [
#         "Web development",
#         "server-side scripting",
#         "e-commerce",
#         "content management systems",
#         "social networking sites"
#     ],
#     "Swift": [
#         "iOS app development",
#         "macOS app development",
#         "Apple Watch app development",
#         "server-side programming"
#     ],
#     "Kotlin": [
#         "Android app development",
#         "web development",
#         "server-side development",
#         "desktop development",
#         "gaming"
#     ],
#     "Go": [
#         "Web development",
#         "networking",
#         "systems programming",
#         "cloud computing",
#         "machine learning",
#         "game development"
#     ],
#     "TypeScript": [
#         "Web development",
#         "front-end development",
#         "server-side development",
#         "desktop development",
#         "mobile app development"
#     ],
#     "Rust": [
#         "Systems programming",
#         "network programming",
#         "game development",
#         "web development",
#         "blockchain development"
#     ],
#     "SQL": [
#         "Database management",
#         "data analysis",
#         "data processing"
#     ],
#     "Objective-C": [
#         "iOS app development",
#         "macOS app development",
#         "desktop app development",
#         "game development"
#     ],
#     "R": [
#         "Statistical computing",
#         "data analysis",
#         "machine learning",
#         "data visualization"
#     ],
#     "MATLAB": [
#         "Numerical computing",
#         "data analysis",
#         "visualization",
#         "machine learning",
#         "signal processing",
#         "control systems"
#     ],
#     "Perl": [
#         "Web development",
#         "systems administration",
#         "network programming",
#         "text processing",
#         "automation",
#         "bioinformatics"
#     ],
#     "Lua": [
#         "Gaming",
#         "scripting",
#         "web development",
#         "embedded systems",
#         "artificial intelligence"
#     ],
#     "Scala": [
#         "Web development",
#         "big data processing",
#         "scientific computing",
#         "artificial intelligence",
#         "data analysis"
#     ],
#     "Haskell": [
#         "Web development",
#         "data analysis",
#         "artificial intelligence",
#         "scientific computing",
#         "blockchain development"
#     ],
#     "Dart": [
#         "Web development",
#         "mobile app development",
#         "server-side development",
#         "desktop development",
#         "game development"
#     ],
#     "Julia": [
#         "Scientific computing",
#         "numerical analysis",
#         "data science",
#         "machine learning",
#         "artificial intelligence"
#     ],
#     "Groovy": [
#         "Web development",
#         "scripting",
#         "automation",
#         "testing",
#         "data analysis",
#         "scientific computing"
#     ],
#     "Clojure": [
#         "Web development",
#         "server-side development",
#         "big data processing",
#         "scientific computing",
#         "artificial intelligence"
#     ],
#     "F#": [
#         "Web development",
#         "server-side development",
#         "scientific computing",
#         "data processing",
#         "artificial intelligence"
#     ],
#     "Erlang": [
#         "Distributed computing",
#         "messaging systems",
#         "telecoms",
#         "concurrency",
#         "fault-tolerant systems"
#     ],
#     "OCaml": [
#         "Scientific computing",
#         "numerical analysis",
#         "symbolic computation",
#         "data analysis",
#         "machine learning"
#     ],
#     "Lisp": [
#         "Artificial intelligence",
#         "scientific computing",
#         "symbolic computation",
#         "game development",
#         "web development"
#     ],
#     "Scheme": [
#         "Artificial intelligence",
#         "scientific computing",
#         "symbolic computation",
#         "game development",
#         "web development"
#     ],
#     "Prolog": [
#         "Artificial intelligence",
#         "natural language processing",
#         "symbolic computation",
#         "expert systems",
#         "planning systems"
#     ],
#     "Ada": [
#         "Aerospace and defense",
#         "transportation",
#         "healthcare",
#         "industrial automation",
#         "telecommunications",
#         "financial services"
#     ],
#     "Cobol": [
#         "Financial services",
#         "healthcare",
#         "government",
#         "insurance",
#         "banking",
#         "transportation"
#     ],
#     "Fortran": [
#         "Scientific computing",
#         "engineering",
#         "weather forecasting",
#         "computational fluid dynamics",
#         "physics",
#         "chemistry"
#     ],
#     "Pascal": [
#         "Education",
#         "scientific computing",
#         "engineering",
#         "gaming",
#         "desktop applications"
#     ],
#     "Assembly Language": [
#         "Low-level systems programming",
#         "device driver development",
#         "embedded systems",
#         "game development"
#     ],
#     "Bash": [
#         "Systems administration",
#         "automation",
#         "scripting",
#         "command-line interface development"
#     ],
#     "PowerShell": [
#         "Systems administration",
#         "automation",
#         "scripting",
#         "command-line interface development"
#     ],
#     "Crystal": [
#         "Web development",
#         "network programming",
#         "systems programming",
#         "game development"
#     ],
#     "Elixir": [
#         "Web development",
#         "concurrency",
#         "distributed systems",
#         "real-time applications",
#         "IoT"
#     ],
#     "ReasonML": [
#         "Front-end web development",
#         "server-side development",
#         "mobile app development"
#     ],
#     "CoffeeScript": [
#         "Web development",
#         "front-end development",
#         "server-side development",
#         "desktop development",
#         "game development"
#     ],
#     "Elm": [
#         "Web development",
#         "front-end development",
#         "game development"
#     ],
#     "Racket": [
#         "Web development",
#         "game development",
#         "scripting",
#         "education",
#         "research"
#     ],
#     "Perl 6": [
#         "Web development",
#         "systems administration",
#         "network programming",
#         "text processing",
#         "automation",
#         "bioinformatics"
#     ],
#     "Tcl": [
#         "Web development",
#         "scripting",
#         "automation",
#         "testing",
#         "embedded systems"
#     ],
#     "Smalltalk": [
#         "Object-oriented programming",
#         "graphical user interfaces",
#         "education"
#     ],
#     "BASIC": [
#         "Education",
#         "simple software development",
#         "scripting"
#     ],
#     "PL/I": [
#         "Business applications",
#         "scientific computing",
#         "database management"
#     ],
#     "Algol": [
#         "Scientific computing",
#         "algorithm development"
#     ],
#     "APL": [
#         "Numerical computing",
#         "scientific computing",
#         "data analysis"
#     ],
#     "Awk": [
#         "Text processing",
#         "scripting",
#         "data extraction and reporting"
#     ],
#     "Ceylon": [
#         "Web development",
#         "enterprise software development",
#         "functional programming"
#     ],
#     "Chapel": [
#         "Parallel programming",
#         "high-performance computing"
#     ],
#     "Common Lisp": [
#         "Artificial intelligence",
#         "scientific computing",
#         "symbolic computation",
#         "web development"
#     ],
#     "D": [
#         "Systems programming",
#         "game development",
#         "scientific computing"
#     ],
#     "Factor": [
#         "Concatenative programming",
#         "metaprogramming",
#         "DSL creation"
#     ],
#     "Forth": [
#         "Embedded systems",
#         "low-level systems programming",
#         "real-time applications"
#     ],
#     "Haxe": [
#         "Cross-platform development",
#         "web development",
#         "game development"
#     ],
#     "Icon": [
#         "Text processing",
#         "scripting",
#         "education",
#         "symbolic computation"
#     ],
#     "Io": [
#         "Web development",
#         "networking",
#         "distributed systems",
#         "game development"
#     ],
#     "J": [
#         "Numerical computing",
#         "scientific computing",
#         "data analysis"
#     ],
#     "K": [
#         "Numerical computing",
#         "data analysis",
#         "scientific computing"
#     ],
#     "LabVIEW": [
#         "Scientific and engineering applications",
#         "data acquisition and analysis",
#         "control systems"
#     ],
#     "Limbo": [
#         "Systems programming",
#         "network programming",
#         "distributed systems",
#         "security"
#     ],
#     "Logo": [
#         "Education",
#         "graphical programming",
#         "simple game development"
#     ],
#     "Mercury": [
#         "Logic programming",
#         "functional programming",
#         "constraint programming"
#     ],
#     "Mirah": [
#         "Android app development",
#         "game development"
#     ],
#     "Nim": [
#         "General-purpose programming",
#         "game development",
#         "scripting",
#         "systems programming"
#     ],
#     "Objective Caml": [
#         "Scientific computing",
#         "symbolic computation",
#         "artificial intelligence",
#         "systems programming"
#     ],
#     "Oz": [
#         "Artificial intelligence",
#         "concurrent programming",
#         "distributed programming"
#     ],
#     "Parrot": [
#         "Dynamic languages",
#         "virtual machines",
#         "compilers"
#     ],
#     "Pike": [
#         "Web development",
#         "networking",
#         "game development",
#         "systems programming"
#     ],
#     "PostScript": [
#         "Desktop publishing",
#         "document preparation",
#         "printing"
#     ],
#     "Processing": [
#         "Data visualization",
#         "interactive art",
#         "graphical user interfaces",
#         "education"
#     ],
#     "Pure Data": [
#         "Sound and music programming",
#         "data visualization",
#         "real-time interaction"
#     ],
#     "PureScript": [
#         "Web development",
#         "functional programming",
#         "front-end development"
#     ],
#     "Q": [
#         "Finance",
#         "big data processing",
#         "distributed computing"
#     ],
#     "REXX": [
#         "System administration",
#         "scripting",
#         "automation",
#         "networking",
#         "text processing"
#     ],
#     "RubyMotion": [
#         "Mobile app development for iOS and Android"
#     ],
#     "SAS": [
#         "Data analysis",
#         "statistical modeling",
#         "business intelligence"
#     ],
#     "Self": [
#         "Object-oriented programming",
#         "dynamic programming",
#         "experimentation"
#     ],
#     "SPARK": [
#         "High-assurance software development",
#         "concurrent and distributed programming"
#     ],
#     "Tcl/Tk": [
#         "Scripting",
#         "GUI development",
#         "automation",
#         "system administration"
#     ],
#     "VHDL": [
#         "Hardware description language",
#         "digital circuit design"
#     ],
#     "Visual Basic": [
#         "Windows desktop application development",
#         "database programming",
#         "automation"
#     ],
#     "Xojo": [
#         "Cross-platform desktop and web application development"
#     ],
#     "Xtend": [
#         "Object-oriented programming",
#         "domain-specific languages",
#         "Java bytecode generation"
#     ]
# }

# %%
from eule import euler

# Pizza to exclusive ingredient
euler_languages = euler(languages);

print(json_prettify(euler_languages));
# Out:
# {
#     "Erlang": [
#         "telecoms",
#         "messaging systems",
#         "Distributed computing",
#         "fault-tolerant systems"
#     ],
#     "Elixir,Erlang": [
#         "concurrency"
#     ],
#     "Awk,Icon": [
#         "Text processing"
#     ],
#     "Common Lisp,Icon,Lisp,OCaml,Objective Caml,Prolog,Scheme": [
#         "symbolic computation"
#     ],
#     "Icon,Processing,Racket,Smalltalk": [
#         "education"
#     ],
#     "Awk,BASIC,Bash,Groovy,Icon,Lua,Nim,PowerShell,REXX,Racket,Ruby,Tcl": [
#         "scripting"
#     ],
#     "SAS": [
#         "business intelligence",
#         "Data analysis",
#         "statistical modeling"
#     ],
#     "Ada": [
#         "Aerospace and defense",
#         "financial services",
#         "telecommunications",
#         "industrial automation"
#     ],
#     "Ada,Cobol": [
#         "healthcare",
#         "transportation"
#     ],
#     "C++": [
#         "finance",
#         "robotics",
#         "Operating systems",
#         "database systems"
#     ],
#     "C++,Parrot": [
#         "compilers"
#     ],
#     "C++,Java,Kotlin,Pascal": [
#         "gaming"
#     ],
#     "APL,C++,Clojure,Common Lisp,D,F#,Groovy,Haskell,J,Java,K,Lisp,PL/I,Pascal,Python,Scala,Scheme": [
#         "scientific computing"
#     ],
#     "C++,Clojure,F#,Haskell,Julia,Lua,Objective Caml,Python,Scala": [
#         "artificial intelligence"
#     ],
#     "Go": [
#         "cloud computing"
#     ],
#     "Go,Io,Pike,REXX": [
#         "networking"
#     ],
#     "Crystal,Go,Nim,Objective Caml,Pike": [
#         "systems programming"
#     ],
#     "Assembly Language,C#,CoffeeScript,Crystal,D,Dart,Elm,Go,Haxe,Io,JavaScript,Lisp,Mirah,Nim,Objective-C,Pike,Racket,Ruby,Rust,Scheme": [
#         "game development"
#     ],
#     "Ceylon,Clojure,CoffeeScript,Crystal,Dart,Elixir,Elm,F#,Go,Groovy,Haskell,Io,JavaScript,PHP,Perl,Perl 6,Pike,PureScript,Python,Racket,Ruby,Scala,Tcl,TypeScript": [
#         "Web development"
#     ],
#     "Go,Julia,MATLAB,OCaml,Python,R": [
#         "machine learning"
#     ],
#     "Q": [
#         "Finance",
#         "distributed computing"
#     ],
#     "Clojure,Java,Q,Scala": [
#         "big data processing"
#     ],
#     "Self": [
#         "experimentation",
#         "dynamic programming"
#     ],
#     "Self,Smalltalk,Xtend": [
#         "Object-oriented programming"
#     ],
#     "R": [
#         "Statistical computing"
#     ],
#     "Pure Data,R": [
#         "data visualization"
#     ],
#     "APL,Groovy,Haskell,J,K,MATLAB,OCaml,Python,R,SQL,Scala": [
#         "data analysis"
#     ],
#     "Haskell,Rust": [
#         "blockchain development"
#     ],
#     "Algol": [
#         "algorithm development"
#     ],
#     "Algol,Fortran,Julia,OCaml,Objective Caml": [
#         "Scientific computing"
#     ],
#     "Nim": [
#         "General-purpose programming"
#     ],
#     "Julia": [
#         "data science"
#     ],
#     "Julia,OCaml": [
#         "numerical analysis"
#     ],
#     "Bash,PowerShell": [
#         "Systems administration",
#         "command-line interface development"
#     ],
#     "Bash,Groovy,Perl,Perl 6,PowerShell,Python,REXX,Ruby,Tcl,Tcl/Tk,Visual Basic": [
#         "automation"
#     ],
#     "Processing,Smalltalk": [
#         "graphical user interfaces"
#     ],
#     "Mercury": [
#         "constraint programming",
#         "Logic programming"
#     ],
#     "Ceylon,Mercury,PureScript": [
#         "functional programming"
#     ],
#     "Java": [
#         "Enterprise software development"
#     ],
#     "Java,Kotlin,Mirah": [
#         "Android app development"
#     ],
#     "C#,Common Lisp,Haxe,Java,Kotlin,Lisp,Lua,Rust,Scheme": [
#         "web development"
#     ],
#     "MATLAB": [
#         "visualization",
#         "signal processing"
#     ],
#     "LabVIEW,MATLAB": [
#         "control systems"
#     ],
#     "APL,J,K,MATLAB": [
#         "Numerical computing"
#     ],
#     "CoffeeScript,Elm,JavaScript,PureScript,TypeScript": [
#         "front-end development"
#     ],
#     "CoffeeScript,Dart,Kotlin,TypeScript": [
#         "desktop development"
#     ],
#     "Clojure,CoffeeScript,Dart,F#,JavaScript,Kotlin,ReasonML,TypeScript": [
#         "server-side development"
#     ],
#     "C#,Dart,ReasonML,TypeScript": [
#         "mobile app development"
#     ],
#     "Elixir,Io,Limbo": [
#         "distributed systems"
#     ],
#     "Factor": [
#         "Concatenative programming",
#         "metaprogramming",
#         "DSL creation"
#     ],
#     "Elixir": [
#         "IoT"
#     ],
#     "Elixir,Forth": [
#         "real-time applications"
#     ],
#     "Xtend": [
#         "Java bytecode generation",
#         "domain-specific languages"
#     ],
#     "JavaScript": [
#         "mobile applications"
#     ],
#     "JavaScript,Pascal": [
#         "desktop applications"
#     ],
#     "Processing": [
#         "Data visualization",
#         "interactive art"
#     ],
#     "Limbo": [
#         "security"
#     ],
#     "D,Limbo,Rust": [
#         "Systems programming"
#     ],
#     "Crystal,Limbo,Perl,Perl 6,Rust": [
#         "network programming"
#     ],
#     "Objective-C": [
#         "desktop app development"
#     ],
#     "Objective-C,Swift": [
#         "iOS app development",
#         "macOS app development"
#     ],
#     "Common Lisp,Lisp,Oz,Prolog,Scheme": [
#         "Artificial intelligence"
#     ],
#     "SQL": [
#         "Database management"
#     ],
#     "F#,SQL": [
#         "data processing"
#     ],
#     "PostScript": [
#         "Desktop publishing",
#         "document preparation",
#         "printing"
#     ],
#     "VHDL": [
#         "digital circuit design",
#         "Hardware description language"
#     ],
#     "PL/I": [
#         "Business applications",
#         "database management"
#     ],
#     "Perl,Perl 6": [
#         "bioinformatics",
#         "systems administration"
#     ],
#     "Perl,Perl 6,REXX": [
#         "text processing"
#     ],
#     "Racket": [
#         "research"
#     ],
#     "RubyMotion": [
#         "Mobile app development for iOS and Android"
#     ],
#     "Forth": [
#         "low-level systems programming",
#         "Embedded systems"
#     ],
#     "Visual Basic": [
#         "Windows desktop application development",
#         "database programming"
#     ],
#     "Cobol": [
#         "banking",
#         "government",
#         "Financial services",
#         "insurance"
#     ],
#     "ReasonML": [
#         "Front-end web development"
#     ],
#     "C#": [
#         "Windows desktop applications"
#     ],
#     "C#,Ceylon": [
#         "enterprise software development"
#     ],
#     "Swift": [
#         "Apple Watch app development",
#         "server-side programming"
#     ],
#     "PHP": [
#         "e-commerce",
#         "server-side scripting",
#         "content management systems",
#         "social networking sites"
#     ],
#     "Haxe": [
#         "Cross-platform development"
#     ],
#     "Fortran,Pascal": [
#         "engineering"
#     ],
#     "BASIC,Logo,Pascal": [
#         "Education"
#     ],
#     "Chapel": [
#         "Parallel programming",
#         "high-performance computing"
#     ],
#     "Awk": [
#         "data extraction and reporting"
#     ],
#     "BASIC": [
#         "simple software development"
#     ],
#     "Logo": [
#         "graphical programming",
#         "simple game development"
#     ],
#     "Oz": [
#         "concurrent programming",
#         "distributed programming"
#     ],
#     "Ruby": [
#         "rapid prototyping"
#     ],
#     "Groovy,Ruby,Tcl": [
#         "testing"
#     ],
#     "Lua": [
#         "Gaming"
#     ],
#     "Assembly Language,Lua,Tcl": [
#         "embedded systems"
#     ],
#     "Prolog": [
#         "planning systems",
#         "natural language processing",
#         "expert systems"
#     ],
#     "Parrot": [
#         "virtual machines",
#         "Dynamic languages"
#     ],
#     "REXX": [
#         "System administration"
#     ],
#     "Xojo": [
#         "Cross-platform desktop and web application development"
#     ],
#     "Pure Data": [
#         "Sound and music programming",
#         "real-time interaction"
#     ],
#     "Tcl/Tk": [
#         "Scripting",
#         "GUI development",
#         "system administration"
#     ],
#     "Assembly Language": [
#         "Low-level systems programming",
#         "device driver development"
#     ],
#     "Fortran": [
#         "chemistry",
#         "computational fluid dynamics",
#         "weather forecasting",
#         "physics"
#     ],
#     "SPARK": [
#         "High-assurance software development",
#         "concurrent and distributed programming"
#     ],
#     "LabVIEW": [
#         "Scientific and engineering applications",
#         "data acquisition and analysis"
#     ]
# }

# %%
from collections import Counter, OrderedDict

class OrderedCounter(Counter, OrderedDict):
    pass


applications=inverse_dict(languages)

delimiter=' '

categories=list(set([category.lower() for category in flatten(list(languages.values()))]))
category_words=list(flatten([category.split(delimiter) for category in categories]))

sorted(Counter(category_words).items(), key=lambda pair: pair[1], reverse=True)
# Out:
# [('development', 25),
#  ('programming', 18),
#  ('systems', 13),
#  ('and', 8),
#  ('desktop', 7),
#  ('app', 7),
#  ('data', 7),
#  ('applications', 6),
#  ('computing', 6),
#  ('processing', 5),
#  ('distributed', 4),
#  ('database', 3),
#  ('mobile', 3),
#  ('web', 3),
#  ('software', 3),
#  ('analysis', 3),
#  ('server-side', 3),
#  ('game', 2),
#  ('simple', 2),
#  ('cross-platform', 2),
#  ('windows', 2),
#  ('application', 2),
#  ('statistical', 2),
#  ('networking', 2),
#  ('ios', 2),
#  ('android', 2),
#  ('intelligence', 2),
#  ('scripting', 2),
#  ('visualization', 2),
#  ('dynamic', 2),
#  ('languages', 2),
#  ('real-time', 2),
#  ('scientific', 2),
#  ('engineering', 2),
#  ('business', 2),
#  ('front-end', 2),
#  ('management', 2),
#  ('language', 2),
#  ('concurrent', 2),
#  ('automation', 2),
#  ('numerical', 2),
#  ('graphical', 2),
#  ('administration', 2),
#  ('embedded', 1),
#  ('aerospace', 1),
#  ('defense', 1),
#  ('planning', 1),
#  ('healthcare', 1),
#  ('virtual', 1),
#  ('machines', 1),
#  ('logic', 1),
#  ('education', 1),
#  ('security', 1),
#  ('bioinformatics', 1),
#  ('telecommunications', 1),
#  ('modeling', 1),
#  ('insurance', 1),
#  ('general-purpose', 1),
#  ('social', 1),
#  ('sites', 1),
#  ('robotics', 1),
#  ('computational', 1),
#  ('fluid', 1),
#  ('dynamics', 1),
#  ('for', 1),
#  ('chemistry', 1),
#  ('cloud', 1),
#  ('artificial', 1),
#  ('interaction', 1),
#  ('transportation', 1),
#  ('machine', 1),
#  ('learning', 1),
#  ('constraint', 1),
#  ('physics', 1),
#  ('domain-specific', 1),
#  ('enterprise', 1),
#  ('object-oriented', 1),
#  ('hardware', 1),
#  ('description', 1),
#  ('algorithm', 1),
#  ('text', 1),
#  ('science', 1),
#  ('expert', 1),
#  ('finance', 1),
#  ('experimentation', 1),
#  ('government', 1),
#  ('weather', 1),
#  ('forecasting', 1),
#  ('operating', 1),
#  ('network', 1),
#  ('printing', 1),
#  ('apple', 1),
#  ('watch', 1),
#  ('high-assurance', 1),
#  ('java', 1),
#  ('bytecode', 1),
#  ('generation', 1),
#  ('publishing', 1),
#  ('content', 1),
#  ('parallel', 1),
#  ('high-performance', 1),
#  ('natural', 1),
#  ('banking', 1),
#  ('user', 1),
#  ('interfaces', 1),
#  ('e-commerce', 1),
#  ('concurrency', 1),
#  ('compilers', 1),
#  ('gui', 1),
#  ('control', 1),
#  ('rapid', 1),
#  ('prototyping', 1),
#  ('iot', 1),
#  ('acquisition', 1),
#  ('telecoms', 1),
#  ('low-level', 1),
#  ('sound', 1),
#  ('music', 1),
#  ('industrial', 1),
#  ('digital', 1),
#  ('circuit', 1),
#  ('design', 1),
#  ('gaming', 1),
#  ('messaging', 1),
#  ('functional', 1),
#  ('macos', 1),
#  ('dsl', 1),
#  ('creation', 1),
#  ('device', 1),
#  ('driver', 1),
#  ('research', 1),
#  ('concatenative', 1),
#  ('metaprogramming', 1),
#  ('fault-tolerant', 1),
#  ('interactive', 1),
#  ('art', 1),
#  ('signal', 1),
#  ('testing', 1),
#  ('symbolic', 1),
#  ('computation', 1),
#  ('blockchain', 1),
#  ('system', 1),
#  ('document', 1),
#  ('preparation', 1),
#  ('financial', 1),
#  ('services', 1),
#  ('big', 1),
#  ('extraction', 1),
#  ('reporting', 1),
#  ('command-line', 1),
#  ('interface', 1)]

# %%
category_words=list(set(category_words))

word_to_categories=dict(map(lambda word: [word, []], category_words))

for word in category_words:
    for category in categories:
        if(word in category):
            word_to_categories[word].append(category)
            
print(json_prettify(word_to_categories))
# Out:
# {
#     "machines": [
#         "virtual machines"
#     ],
#     "high-performance": [
#         "high-performance computing"
#     ],
#     "sound": [
#         "sound and music programming"
#     ],
#     "hardware": [
#         "hardware description language"
#     ],
#     "app": [
#         "mobile applications",
#         "windows desktop application development",
#         "windows desktop applications",
#         "mobile app development for ios and android",
#         "desktop applications",
#         "cross-platform desktop and web application development",
#         "scientific and engineering applications",
#         "business applications",
#         "apple watch app development",
#         "desktop app development",
#         "android app development",
#         "ios app development",
#         "real-time applications",
#         "macos app development",
#         "mobile app development"
#     ],
#     "healthcare": [
#         "healthcare"
#     ],
#     "domain-specific": [
#         "domain-specific languages"
#     ],
#     "symbolic": [
#         "symbolic computation"
#     ],
#     "desktop": [
#         "windows desktop application development",
#         "windows desktop applications",
#         "desktop applications",
#         "cross-platform desktop and web application development",
#         "desktop app development",
#         "desktop publishing",
#         "desktop development"
#     ],
#     "front-end": [
#         "front-end development",
#         "front-end web development"
#     ],
#     "processing": [
#         "text processing",
#         "natural language processing",
#         "data processing",
#         "signal processing",
#         "big data processing"
#     ],
#     "cross-platform": [
#         "cross-platform development",
#         "cross-platform desktop and web application development"
#     ],
#     "learning": [
#         "machine learning"
#     ],
#     "education": [
#         "education"
#     ],
#     "services": [
#         "financial services"
#     ],
#     "security": [
#         "security"
#     ],
#     "bioinformatics": [
#         "bioinformatics"
#     ],
#     "telecommunications": [
#         "telecommunications"
#     ],
#     "insurance": [
#         "insurance"
#     ],
#     "web": [
#         "web development",
#         "cross-platform desktop and web application development",
#         "front-end web development"
#     ],
#     "user": [
#         "graphical user interfaces"
#     ],
#     "design": [
#         "digital circuit design"
#     ],
#     "development": [
#         "game development",
#         "simple game development",
#         "cross-platform development",
#         "windows desktop application development",
#         "mobile app development for ios and android",
#         "web development",
#         "cross-platform desktop and web application development",
#         "enterprise software development",
#         "front-end development",
#         "algorithm development",
#         "apple watch app development",
#         "high-assurance software development",
#         "desktop app development",
#         "android app development",
#         "server-side development",
#         "ios app development",
#         "simple software development",
#         "desktop development",
#         "gui development",
#         "macos app development",
#         "device driver development",
#         "blockchain development",
#         "front-end web development",
#         "mobile app development",
#         "command-line interface development"
#     ],
#     "sites": [
#         "social networking sites"
#     ],
#     "acquisition": [
#         "data acquisition and analysis"
#     ],
#     "robotics": [
#         "robotics"
#     ],
#     "chemistry": [
#         "chemistry"
#     ],
#     "operating": [
#         "operating systems"
#     ],
#     "macos": [
#         "macos app development"
#     ],
#     "scripting": [
#         "scripting",
#         "server-side scripting"
#     ],
#     "network": [
#         "social networking sites",
#         "network programming",
#         "networking"
#     ],
#     "creation": [
#         "dsl creation"
#     ],
#     "concurrent": [
#         "concurrent programming",
#         "concurrent and distributed programming"
#     ],
#     "driver": [
#         "device driver development"
#     ],
#     "administration": [
#         "systems administration",
#         "system administration"
#     ],
#     "transportation": [
#         "transportation"
#     ],
#     "gui": [
#         "gui development"
#     ],
#     "functional": [
#         "functional programming"
#     ],
#     "parallel": [
#         "parallel programming"
#     ],
#     "text": [
#         "text processing"
#     ],
#     "industrial": [
#         "industrial automation"
#     ],
#     "constraint": [
#         "constraint programming"
#     ],
#     "preparation": [
#         "document preparation"
#     ],
#     "game": [
#         "game development",
#         "simple game development"
#     ],
#     "physics": [
#         "physics"
#     ],
#     "windows": [
#         "windows desktop application development",
#         "windows desktop applications"
#     ],
#     "language": [
#         "dynamic languages",
#         "domain-specific languages",
#         "hardware description language",
#         "natural language processing"
#     ],
#     "modeling": [
#         "statistical modeling"
#     ],
#     "natural": [
#         "natural language processing"
#     ],
#     "algorithm": [
#         "algorithm development"
#     ],
#     "graphical": [
#         "graphical programming",
#         "graphical user interfaces"
#     ],
#     "for": [
#         "cross-platform development",
#         "bioinformatics",
#         "mobile app development for ios and android",
#         "cross-platform desktop and web application development",
#         "weather forecasting",
#         "high-performance computing"
#     ],
#     "data": [
#         "database systems",
#         "data visualization",
#         "database management",
#         "data science",
#         "data analysis",
#         "data processing",
#         "data acquisition and analysis",
#         "database programming",
#         "big data processing",
#         "data extraction and reporting"
#     ],
#     "computing": [
#         "cloud computing",
#         "statistical computing",
#         "distributed computing",
#         "scientific computing",
#         "numerical computing",
#         "high-performance computing"
#     ],
#     "digital": [
#         "digital circuit design"
#     ],
#     "circuit": [
#         "digital circuit design"
#     ],
#     "defense": [
#         "aerospace and defense"
#     ],
#     "interactive": [
#         "interactive art"
#     ],
#     "simple": [
#         "simple game development",
#         "simple software development"
#     ],
#     "big": [
#         "big data processing"
#     ],
#     "distributed": [
#         "distributed systems",
#         "distributed programming",
#         "distributed computing",
#         "concurrent and distributed programming"
#     ],
#     "and": [
#         "aerospace and defense",
#         "mobile app development for ios and android",
#         "cross-platform desktop and web application development",
#         "scientific and engineering applications",
#         "android app development",
#         "data acquisition and analysis",
#         "concurrent and distributed programming",
#         "sound and music programming",
#         "data extraction and reporting",
#         "command-line interface development"
#     ],
#     "android": [
#         "mobile app development for ios and android",
#         "android app development"
#     ],
#     "finance": [
#         "finance"
#     ],
#     "reporting": [
#         "data extraction and reporting"
#     ],
#     "dsl": [
#         "dsl creation"
#     ],
#     "computation": [
#         "computational fluid dynamics",
#         "symbolic computation"
#     ],
#     "experimentation": [
#         "experimentation"
#     ],
#     "logic": [
#         "logic programming"
#     ],
#     "content": [
#         "content management systems"
#     ],
#     "publishing": [
#         "desktop publishing"
#     ],
#     "embedded": [
#         "embedded systems"
#     ],
#     "engineering": [
#         "scientific and engineering applications",
#         "engineering"
#     ],
#     "government": [
#         "government"
#     ],
#     "programming": [
#         "logic programming",
#         "general-purpose programming",
#         "constraint programming",
#         "distributed programming",
#         "object-oriented programming",
#         "systems programming",
#         "concurrent programming",
#         "network programming",
#         "parallel programming",
#         "server-side programming",
#         "graphical programming",
#         "concurrent and distributed programming",
#         "low-level systems programming",
#         "sound and music programming",
#         "database programming",
#         "functional programming",
#         "concatenative programming",
#         "metaprogramming",
#         "dynamic programming"
#     ],
#     "signal": [
#         "signal processing"
#     ],
#     "aerospace": [
#         "aerospace and defense"
#     ],
#     "database": [
#         "database systems",
#         "database management",
#         "database programming"
#     ],
#     "high-assurance": [
#         "high-assurance software development"
#     ],
#     "object-oriented": [
#         "object-oriented programming"
#     ],
#     "device": [
#         "device driver development"
#     ],
#     "messaging": [
#         "messaging systems"
#     ],
#     "intelligence": [
#         "artificial intelligence",
#         "business intelligence"
#     ],
#     "printing": [
#         "printing"
#     ],
#     "software": [
#         "enterprise software development",
#         "high-assurance software development",
#         "simple software development"
#     ],
#     "dynamic": [
#         "computational fluid dynamics",
#         "dynamic languages",
#         "dynamic programming"
#     ],
#     "statistical": [
#         "statistical modeling",
#         "statistical computing"
#     ],
#     "java": [
#         "java bytecode generation"
#     ],
#     "extraction": [
#         "data extraction and reporting"
#     ],
#     "prototyping": [
#         "rapid prototyping"
#     ],
#     "management": [
#         "database management",
#         "content management systems"
#     ],
#     "artificial": [
#         "artificial intelligence"
#     ],
#     "automation": [
#         "automation",
#         "industrial automation"
#     ],
#     "interaction": [
#         "real-time interaction"
#     ],
#     "weather": [
#         "weather forecasting"
#     ],
#     "computational": [
#         "computational fluid dynamics"
#     ],
#     "system": [
#         "embedded systems",
#         "database systems",
#         "planning systems",
#         "distributed systems",
#         "expert systems",
#         "systems programming",
#         "operating systems",
#         "content management systems",
#         "systems administration",
#         "control systems",
#         "low-level systems programming",
#         "messaging systems",
#         "fault-tolerant systems",
#         "system administration"
#     ],
#     "interface": [
#         "graphical user interfaces",
#         "command-line interface development"
#     ],
#     "generation": [
#         "java bytecode generation"
#     ],
#     "virtual": [
#         "virtual machines"
#     ],
#     "scientific": [
#         "scientific and engineering applications",
#         "scientific computing"
#     ],
#     "watch": [
#         "apple watch app development"
#     ],
#     "dynamics": [
#         "computational fluid dynamics"
#     ],
#     "visualization": [
#         "data visualization",
#         "visualization"
#     ],
#     "banking": [
#         "banking"
#     ],
#     "music": [
#         "sound and music programming"
#     ],
#     "apple": [
#         "apple watch app development"
#     ],
#     "machine": [
#         "virtual machines",
#         "machine learning"
#     ],
#     "e-commerce": [
#         "e-commerce"
#     ],
#     "financial": [
#         "financial services"
#     ],
#     "concurrency": [
#         "concurrency"
#     ],
#     "real-time": [
#         "real-time interaction",
#         "real-time applications"
#     ],
#     "art": [
#         "artificial intelligence",
#         "interactive art"
#     ],
#     "general-purpose": [
#         "general-purpose programming"
#     ],
#     "server-side": [
#         "server-side scripting",
#         "server-side development",
#         "server-side programming"
#     ],
#     "compilers": [
#         "compilers"
#     ],
#     "control": [
#         "control systems"
#     ],
#     "document": [
#         "document preparation"
#     ],
#     "mobile": [
#         "mobile applications",
#         "mobile app development for ios and android",
#         "mobile app development"
#     ],
#     "interfaces": [
#         "graphical user interfaces"
#     ],
#     "systems": [
#         "embedded systems",
#         "database systems",
#         "planning systems",
#         "distributed systems",
#         "expert systems",
#         "systems programming",
#         "operating systems",
#         "content management systems",
#         "systems administration",
#         "control systems",
#         "low-level systems programming",
#         "messaging systems",
#         "fault-tolerant systems"
#     ],
#     "ios": [
#         "mobile app development for ios and android",
#         "ios app development"
#     ],
#     "iot": [
#         "iot"
#     ],
#     "expert": [
#         "expert systems"
#     ],
#     "numerical": [
#         "numerical computing",
#         "numerical analysis"
#     ],
#     "enterprise": [
#         "enterprise software development"
#     ],
#     "science": [
#         "data science"
#     ],
#     "telecoms": [
#         "telecoms"
#     ],
#     "concatenative": [
#         "concatenative programming"
#     ],
#     "business": [
#         "business applications",
#         "business intelligence"
#     ],
#     "description": [
#         "hardware description language"
#     ],
#     "gaming": [
#         "gaming"
#     ],
#     "fluid": [
#         "computational fluid dynamics"
#     ],
#     "command-line": [
#         "command-line interface development"
#     ],
#     "forecasting": [
#         "weather forecasting"
#     ],
#     "networking": [
#         "social networking sites",
#         "networking"
#     ],
#     "analysis": [
#         "data analysis",
#         "numerical analysis",
#         "data acquisition and analysis"
#     ],
#     "languages": [
#         "dynamic languages",
#         "domain-specific languages"
#     ],
#     "research": [
#         "research"
#     ],
#     "bytecode": [
#         "java bytecode generation"
#     ],
#     "blockchain": [
#         "blockchain development"
#     ],
#     "fault-tolerant": [
#         "fault-tolerant systems"
#     ],
#     "metaprogramming": [
#         "metaprogramming"
#     ],
#     "planning": [
#         "planning systems"
#     ],
#     "social": [
#         "social networking sites"
#     ],
#     "testing": [
#         "testing"
#     ],
#     "low-level": [
#         "low-level systems programming"
#     ],
#     "rapid": [
#         "rapid prototyping"
#     ],
#     "application": [
#         "mobile applications",
#         "windows desktop application development",
#         "windows desktop applications",
#         "desktop applications",
#         "cross-platform desktop and web application development",
#         "scientific and engineering applications",
#         "business applications",
#         "real-time applications"
#     ],
#     "cloud": [
#         "cloud computing"
#     ],
#     "applications": [
#         "mobile applications",
#         "windows desktop applications",
#         "desktop applications",
#         "scientific and engineering applications",
#         "business applications",
#         "real-time applications"
#     ]
# }
