# %% [markdown]
# # Com dimensão

# %%
# %%time
from ortools.sat.python import cp_model
import pandas

#---------------------------------------------------
# data 
#---------------------------------------------------

data = {'bin':{'h':60,'w':40},
        'cat1':{'w': 7,'h':12,'items':10},
        'cat2':{'w': 9,'h': 3,'items':10},
        'cat3':{'w': 5,'h':14,'items':10},
        'cat4':{'w':13,'h': 9,'items':10},
        'cat5':{'w': 6,'h': 8,'items': 5},
        'cat6':{'w':20,'h': 5,'items': 5}}      

#
# extract data for easier access
#

# bin width and height
H = data['bin']['h']
W = data['bin']['w']

# h,w,cat for each item
h = [data[cat]['h'] for cat in data if cat!='bin' for i in range(data[cat]['items'])]
w = [data[cat]['w'] for cat in data if cat!='bin' for i in range(data[cat]['items'])]
cat = [cat for cat in data if cat!='bin' for i in range(data[cat]['items'])]
n = len(h)  # number of items
m = 10  # max number of bins

#---------------------------------------------------
# or-tools model 
#---------------------------------------------------

model = cp_model.CpModel()

#
# variables
#

# x and y
x = [model.NewIntVar(0,W-w[i],f'x{i}') for i in range(n)]

xb1 = [model.NewIntVar(0,m*W-w[i],f'xb1.{i}') for i in range(n)]
xb2 = [model.NewIntVar(w[i],m*W,f'xb2.{i}') for i in range(n)]

y1 = [model.NewIntVar(0,H-h[i],f'y1.{i}') for i in range(n)]
y2 = [model.NewIntVar(h[i],H,f'y2.{i}') for i in range(n)]

# interval variables
xival = [model.NewIntervalVar(xb1[i],w[i],xb2[i],f'xival{i}') for i in range(n)]
yival = [model.NewIntervalVar(y1[i],h[i],y2[i],f'yival{i}') for i in range(n)]

# bin numbers
b = [model.NewIntVar(0,m-1,f'b{i}') for i in range(n)]

# objective
z = model.NewIntVar(0,m-1,'z')

#
# constraints
#
for i in range(n):
  model.Add(xb1[i] == x[i] + b[i]*W)
  model.Add(xb2[i] == xb1[i] + w[i])

model.AddNoOverlap2D(xival,yival)

model.AddMaxEquality(z,[b[i] for i in range(n)])

# objective
model.Minimize(z)    

#
# solve model
#
solver = cp_model.CpSolver()

# log does not work inside a Jupyter notebook
solver.parameters.log_search_progress = True
rc = solver.Solve(model)
print(f"return code:{rc}")
print(f"status:{solver.StatusName()}")

if rc == 4:
    df = pandas.DataFrame({ 
        'bin' : [solver.Value(b[i]) for i in range(n)],
        'x'   : [solver.Value(x[i]) for i in range(n)],
        'y'   : [solver.Value(y1[i]) for i in range(n)],
        'w'   : w,
        'h'   : h})
    display(df)
# Out:
# Starting CP-SAT solver v9.7.2996
# Parameters: log_search_progress: true
# Setting number of workers to 8
#
# Initial optimization model '': (model_fingerprint: 0x939297ecad356fad)
# #Variables: 301 (#ints: 1 in objective)
#   - 51 in [0,9]
#   - 5 in [0,20]
#   - 10 in [0,27]
#   - 10 in [0,31]
#   - 10 in [0,33]
#   - 5 in [0,34]
#   - 10 in [0,35]
#   - 10 in [0,46]
#   - 10 in [0,48]
#   - 10 in [0,51]
#   - 5 in [0,52]
#   - 5 in [0,55]
#   - 10 in [0,57]
#   - 5 in [0,380]
#   - 10 in [0,387]
#   - 10 in [0,391]
#   - 10 in [0,393]
#   - 5 in [0,394]
#   - 10 in [0,395]
#   - 10 in [3,60]
#   - 5 in [5,60]
#   - 10 in [5,400]
#   - 5 in [6,400]
#   - 10 in [7,400]
#   - 5 in [8,60]
#   - 10 in [9,60]
#   - 10 in [9,400]
#   - 10 in [12,60]
#   - 10 in [13,400]
#   - 10 in [14,60]
#   - 5 in [20,400]
# #kInterval: 100
# #kLinMax: 1 (#expressions: 50)
# #kLinear2: 150
# #kLinear3: 50
# #kNoOverlap2D: 1 (#rectangles: 50)
#
# Starting presolve at 0.00s
# [ExtractEncodingFromLinear] #potential_supersets=0 #potential_subsets=0 #at_most_one_encodings=0 #exactly_one_encodings=0 #unique_terms=0 #multiple_terms=0 #literals=0 time=1.767e-06s
# [Symmetry] Graph for symmetry has 753 nodes and 851 arcs.
# [Symmetry] Symmetry computation done. time: 0.000277997 dtime: 0.0004358
# [Symmetry] #generators: 44, average support size: 6
# [Symmetry] 18 orbits with sizes: 10,10,10,10,10,10,10,10,10,10,...
# [Symmetry] Found orbitope of size 3 x 5
# [DetectDuplicateConstraints] #duplicates=0 #without_enforcements=0 time=4.5222e-05s
# [DetectDominatedLinearConstraints] #relevant_constraints=100 #work_done=600 #num_inclusions=0 #num_redundant=0 time=1.3892e-05s
# [ProcessSetPPC] #relevant_constraints=0 #num_inclusions=0 work=0 time=2.373e-06s
# [FindBigHorizontalLinearOverlap] #blocks=0 #saved_nz=0 #linears=0 #work_done=0/1e+09 time=8.74e-07s
# [FindBigVerticalLinearOverlap] #blocks=0 #nz_reduction=0 #work_done=801 time=1.3472e-05s
# [MergeClauses] #num_collisions=0 #num_merges=0 #num_saved_literals=0 work=0/100000000 time=2.286e-06s
# [Symmetry] Graph for symmetry has 753 nodes and 851 arcs.
# [Symmetry] Symmetry computation done. time: 0.000284794 dtime: 0.0004358
# [Symmetry] #generators: 44, average support size: 6
# [Symmetry] 18 orbits with sizes: 10,10,10,10,10,10,10,10,10,10,...
# [Symmetry] Found orbitope of size 3 x 5
# [DetectDuplicateConstraints] #duplicates=0 #without_enforcements=0 time=3.7986e-05s
# [DetectDominatedLinearConstraints] #relevant_constraints=100 #work_done=600 #num_inclusions=0 #num_redundant=0 time=1.0945e-05s
# [ProcessSetPPC] #relevant_constraints=0 #num_inclusions=0 work=0 time=1.276e-06s
# [FindBigHorizontalLinearOverlap] #blocks=0 #saved_nz=0 #linears=0 #work_done=0/1e+09 time=5.07e-07s
# [FindBigVerticalLinearOverlap] #blocks=0 #nz_reduction=0 #work_done=801 time=8.312e-06s
# [MergeClauses] #num_collisions=0 #num_merges=0 #num_saved_literals=0 work=0/100000000 time=1.576e-06s
# [ExpandObjective] #propagations=0 #entries=0 #tight_variables=0 #tight_constraints=0 #expands=0 #issues=0 time=4.569e-06s
#
# Presolve summary:
#   - 100 affine relations were detected.
#   - rule 'TODO dual: only one blocking constraint?' was applied 900 times.
#   - rule 'TODO dual: only one unspecified blocking constraint?' was applied 6 times.
#   - rule 'TODO symmetry: add symmetry breaking inequalities?' was applied 2 times.
#   - rule 'affine: new relation' was applied 100 times.
#   - rule 'lin_max: rewrite with precedences' was applied 1 time.
#   - rule 'linear: always true' was applied 50 times.
#   - rule 'linear: fixed or dup variables' was applied 50 times.
#   - rule 'linear: reduced variable domains' was applied 50 times.
#   - rule 'linear: remapped using affine relations' was applied 150 times.
#   - rule 'linear: simplified rhs' was applied 50 times.
#   - rule 'linear: singleton column' was applied 50 times.
#   - rule 'presolve: 0 unused variables removed.' was applied 1 time.
#   - rule 'presolve: iteration' was applied 2 times.
#
# Presolved optimization model '': (model_fingerprint: 0xac7706c391e52565)
# #Variables: 151 (#ints: 1 in objective)
#   - 51 in [0,9]
#   - 5 in [0,20][40,60][80,100][120,140][160,180][200,220][240,260][280,300][320,340][360,380]
#   - 10 in [0,27][40,67][80,107][120,147][160,187][200,227][240,267][280,307][320,347][360,387]
#   - 10 in [0,31][40,71][80,111][120,151][160,191][200,231][240,271][280,311][320,351][360,391]
#   - 10 in [0,33][40,73][80,113][120,153][160,193][200,233][240,273][280,313][320,353][360,393]
#   - 5 in [0,34][40,74][80,114][120,154][160,194][200,234][240,274][280,314][320,354][360,394]
#   - 10 in [0,35][40,75][80,115][120,155][160,195][200,235][240,275][280,315][320,355][360,395]
#   - 10 in [0,46]
#   - 10 in [0,48]
#   - 10 in [0,51]
#   - 5 in [0,52]
#   - 5 in [0,55]
#   - 10 in [0,57]
# #kInterval: 100
# #kLinear2: 100
# #kNoOverlap2D: 1 (#rectangles: 50)
#
# Preloading model.
# #Bound   0.00s best:inf   next:[0,9]      initial_domain
# [Symmetry] Graph for symmetry has 603 nodes and 851 arcs.
# [Symmetry] Symmetry computation done. time: 0.000254201 dtime: 0.0004268
# [Symmetry] #generators: 44, average support size: 6
# [Symmetry] Found orbitope of size 3 x 5
# #Model   0.01s var:151/151 constraints:201/201
#
# Starting search at 0.01s with 8 workers.
# 6 full problem subsolvers: [default_lp, max_lp, no_lp, pseudo_costs, quick_restart, reduced_costs]
# 1 first solution subsolver: [random]
# 13 incomplete subsolvers: [feasibility_pump, graph_arc_lns, graph_cst_lns, graph_dec_lns, graph_var_lns, packing_rectangles_lns, packing_slice_lns, rins/rens, rnd_cst_lns, rnd_var_lns, scheduling_intervals_lns, scheduling_precedences_lns, scheduling_time_window_lns]
# 3 helper subsolvers: [neighborhood_helper, synchronization_agent, update_gap_integral]
# #Bound   0.01s best:inf   next:[1,9]      reduced_costs
# #1       0.31s best:2     next:[1,1]      rens_lp_lns(d=0.71 s=12 t=0.10 p=1.00 stall=0)
# #2       0.33s best:1     next:[]         scheduling_precedences_lns(d=0.50 s=20 t=0.10 p=0.00 stall=0) [hint]
#
# Task timing                             n [     min,      max]      avg      dev     time         n [     min,      max]      avg      dev    dtime
#        'synchronization_agent':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#          'neighborhood_helper':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#                   'default_lp':         1 [329.50ms, 329.50ms] 329.50ms   0.00ns 329.50ms         1 [ 13.19ms,  13.19ms]  13.19ms   0.00ns  13.19ms
#                        'no_lp':         1 [329.49ms, 329.49ms] 329.49ms   0.00ns 329.49ms         1 [ 22.20ms,  22.20ms]  22.20ms   0.00ns  22.20ms
#                       'max_lp':         1 [327.46ms, 327.46ms] 327.46ms   0.00ns 327.46ms         1 [ 19.05ms,  19.05ms]  19.05ms   0.00ns  19.05ms
#                'reduced_costs':         1 [323.92ms, 323.92ms] 323.92ms   0.00ns 323.92ms         1 [  4.31ms,   4.31ms]   4.31ms   0.00ns   4.31ms
#                 'pseudo_costs':         1 [323.89ms, 323.89ms] 323.89ms   0.00ns 323.89ms         1 [ 15.34ms,  15.34ms]  15.34ms   0.00ns  15.34ms
#                'quick_restart':         1 [323.88ms, 323.88ms] 323.88ms   0.00ns 323.88ms         1 [ 10.31ms,  10.31ms]  10.31ms   0.00ns  10.31ms
#             'feasibility_pump':         3 [ 54.34us, 363.75us] 234.24us 131.24us 702.72us         2 [  5.44us,   5.44us]   5.44us   0.00ns  10.87us
#                    'rins/rens':         3 [ 55.35us, 291.33ms]  97.83ms 136.82ms 293.50ms         2 [ 48.00ns,   3.05ms]   1.53ms   1.53ms   3.05ms
#                  'rnd_var_lns':         1 [393.47us, 393.47us] 393.47us   0.00ns 393.47us         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#                  'rnd_cst_lns':         1 [  9.47ms,   9.47ms]   9.47ms   0.00ns   9.47ms         1 [  8.62us,   8.62us]   8.62us   0.00ns   8.62us
#                'graph_var_lns':         1 [  6.29ms,   6.29ms]   6.29ms   0.00ns   6.29ms         1 [  6.22us,   6.22us]   6.22us   0.00ns   6.22us
#                'graph_arc_lns':         1 [ 52.79us,  52.79us]  52.79us   0.00ns  52.79us         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#                'graph_cst_lns':         1 [984.35us, 984.35us] 984.35us   0.00ns 984.35us         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#                'graph_dec_lns':         1 [404.44us, 404.44us] 404.44us   0.00ns 404.44us         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#     'scheduling_intervals_lns':         1 [  9.62ms,   9.62ms]   9.62ms   0.00ns   9.62ms         1 [  7.82us,   7.82us]   7.82us   0.00ns   7.82us
#   'scheduling_precedences_lns':         1 [  9.01ms,   9.01ms]   9.01ms   0.00ns   9.01ms         1 [ 10.16us,  10.16us]  10.16us   0.00ns  10.16us
#   'scheduling_time_window_lns':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#       'packing_rectangles_lns':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#            'packing_slice_lns':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#          'update_gap_integral':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#
# Search stats        Bools  Conflicts  Branches  Restarts  BoolPropag  IntegerPropag
#      'default_lp':    446      2'103     9'213        14      63'305         30'613
#           'no_lp':  1'018        970    14'018        17      75'251         73'374
#          'max_lp':    564        663     5'417         6      21'953         12'973
#   'reduced_costs':    504        367     1'686         4       6'197         16'675
#    'pseudo_costs':    534        657     8'674        10      26'995         19'226
#   'quick_restart':  1'460        767    12'520        76      51'785         17'443
#
# LNS stats                        Improv/Calls  Closed  Difficulty  TimeLimit
#                    'rins/rens':           2/2    100%        0.81       0.10
#                  'rnd_var_lns':           0/0      0%        0.50       0.10
#                  'rnd_cst_lns':           0/1    100%        0.71       0.10
#                'graph_var_lns':           0/1    100%        0.71       0.10
#                'graph_arc_lns':           0/0      0%        0.50       0.10
#                'graph_cst_lns':           0/0      0%        0.50       0.10
#                'graph_dec_lns':           0/0      0%        0.50       0.10
#     'scheduling_intervals_lns':           1/1      0%        0.29       0.10
#   'scheduling_precedences_lns':           1/1    100%        0.71       0.10
#   'scheduling_time_window_lns':           0/0      0%        0.50       0.10
#       'packing_rectangles_lns':           0/0      0%        0.50       0.10
#            'packing_slice_lns':           0/0      0%        0.50       0.10
#
# Solutions (2)                    Num   Rank
#                  'rens_lp_lns':    1  [1,1]
#   'scheduling_precedences_lns':    1  [2,2]
#
# Objective bounds     Num
#   'initial_domain':    1
#    'reduced_costs':    1
#
# Solution repositories    Added  Queried  Ignored  Synchro
#   'feasible solutions':      2       16        0        2
#         'lp solutions':     79        2       77        8
#                 'pump':      2        1
#
# Improving bounds shared    Num
#           'pseudo_costs':  101
#          'reduced_costs':    1
#
# return code:4
# status:OPTIMAL
# CPU times: user 2.45 s, sys: 0 ns, total: 2.45 s
# Wall time: 347 ms
# CpSolverResponse summary:
# status: OPTIMAL
# objective: 1
# best_bound: 1
# integers: 151
# booleans: 506
# conflicts: 2359
# branches: 7639
# propagations: 52166
# integer_propagations: 25346
# restarts: 8
# lp_iterations: 0
# walltime: 0.337622
# usertime: 0.337622
# deterministic_time: 0.099448
# gap_integral: 0.0330268
# solution_fingerprint: 0x93acf130d7a367bf

# %%
df
# Out:
#     bin   x   y   w   h
# 0     0  11   0   7  12
# 1     0   0  39   7  12
# 2     0  13  29   7  12
# 3     0  29  43   7  12
# 4     1  28   0   7  12
# 5     0  33  31   7  12
# 6     1   5   9   7  12
# 7     1  12  12   7  12
# 8     1   5  21   7  12
# 9     1  26  12   7  12
# 10    0  26  55   9   3
# 11    0  31   6   9   3
# 12    0   5  16   9   3
# 13    0  18   0   9   3
# 14    1  12   9   9   3
# 15    0   7  47   9   3
# 16    0  31   0   9   3
# 17    0  31   3   9   3
# 18    0  31   9   9   3
# 19    1  31  28   9   3
# 20    0   0   0   5  14
# 21    1   0   9   5  14
# 22    1  21   9   5  14
# 23    0  35  12   5  14
# 24    0  30  17   5  14
# 25    1   0  23   5  14
# 26    1  35  14   5  14
# 27    0  25  17   5  14
# 28    0   0  14   5  14
# 29    1  35   0   5  14
# 30    0   0  30  13   9
# 31    0   0  51  13   9
# 32    1   0  37  13   9
# 33    1  27  31  13   9
# 34    1  13   0  13   9
# 35    0  16  41  13   9
# 36    0  18   3  13   9
# 37    1   0   0  13   9
# 38    0  20  31  13   9
# 39    0  13  50  13   9
# 40    0   5   0   6   8
# 41    0   7  39   6   8
# 42    0   5   8   6   8
# 43    1  34  40   6   8
# 44    1  34  48   6   8
# 45    0   5  19  20   5
# 46    0   5  24  20   5
# 47    1   0  46  20   5
# 48    0  14  12  20   5
# 49    1   0  51  20   5
